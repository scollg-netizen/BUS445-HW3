# %%
import sys
print(sys.executable)
# Out:
# C:\Users\TheLu\anaconda3\python.exe

# %%
def mean_and_max(numbers):
    mean = sum(numbers) / len(numbers)
    maximum = max(numbers)
    return mean, maximum


numbers = [10, 20, 30, 40, 50]

mean, maximum = mean_and_max(numbers)

print("Numbers:", numbers)
print("Mean:", mean)
print("Maximum:", maximum)
# Out:
# Numbers: [10, 20, 30, 40, 50]
# Mean: 30.0
# Maximum: 50

# %% [markdown]
# One difference I noticed between VS Code and Jupyter is that Jupyter lets me run one cell at a time I see the output underneath the cell. In VS Code I worked with the Python file and ran the program from the terminal.
